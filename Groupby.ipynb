# %%
import os
import pandas as pd

# %%
pokemon_csv = "C:\Python\Pokemon.csv"

# %%
# Read with Pandas
pokemon_pd = pd.read_csv(pokemon_csv)
pokemon_pd.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Extract the following columns: "Type 1", "HP", "Attack", "Sp. Atk", "Sp. Def", and "Speed"
pokemon_type = pokemon_pd[["Type 1", "HP", "Attack",
                           "Defense", "Sp. Atk", "Sp. Def", "Speed"]]
pokemon_type.head()
# Out:
#   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  Grass  45      49       49       65       65     45
# 1  Grass  60      62       63       80       80     60
# 2  Grass  80      82       83      100      100     80
# 3  Grass  80     100      123      122      120     80
# 4   Fire  39      52       43       60       50     65

# %%
# dropping passed columns 
#data.drop(["Team", "Weight"], axis = 1, inplace = False)

# %%
# Create a dataframe of the average stats for each type of pokemon.
pokemon_group = pokemon_type.groupby(["Type 1"])
pokemon_group

pokemon_comparison = pokemon_group.mean()
pokemon_comparison
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type 1
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778   65.925926  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# ...

# %%
# Calculate the total power level of each type of pokemon by summing all of the stats together.
# Place the results into a new column.
pokemon_comparison["Total"] = pokemon_comparison.sum(axis=1)

pokemon_comparison["Total"]
# Out:
# Type 1
# Bug         378.927536
# Dark        445.741935
# Dragon      550.531250
# Electric    443.409091
# Fairy       413.176471
# Fighting    416.444444
# Fire        458.076923
# Flying      485.000000
# Ghost       439.562500
# Grass       421.142857
# Ground      437.500000
# Ice         433.458333
# Normal      401.683673
# Poison      399.142857
# Psychic     475.947368
# Rock        453.750000
# Steel       487.703704
# Water       430.455357
# Name: Total, dtype: float64

# %%
# Bonus: Sort the table by strongest type and export the resulting table to a new CSV.
strongest_pokemon = pokemon_comparison.sort_values(["Total"], ascending=False)
strongest_pokemon.to_csv("C:/Python/Pokemon_output.csv", index=True)

# %%
import os
import pandas as pd
import numpy

# %%
csv_path = "C:\Python\Soccer2018Data.csv"

# %%
# Read with Pandas
Soccer2018_pd = pd.read_csv(csv_path)
Soccer2018_pd
Soccer2018_pd.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club Preferred Position   CAM    CB   CDM  ...    RB   RCB  \
# 0       Real Madrid CF                 ST  89.0  53.0  62.0  ...  61.0  53.0
# 1         FC Barcelona                 RW  92.0  45.0  59.0  ...  57.0  45.0
# 2  Paris Saint-Germain                 LW  88.0  46.0  59.0  ...  59.0  46.0
# 3         FC Barcelona                 ST  87.0  58.0  65.0  ...  64.0  58.0
# 4     FC Bayern Munich                 GK   NaN   NaN   NaN  ...   NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# ...

# %%
# Import the CSV into a pandas DataFrame
Soccer2018_df = pd.read_csv(csv_path, low_memory=False)
Soccer2018_df
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0      Cristiano Ronaldo   32             Portugal       94         94
# 1               L. Messi   30            Argentina       93         93
# 2                 Neymar   25               Brazil       92         94
# 3              L. Suárez   30              Uruguay       92         92
# 4               M. Neuer   31              Germany       92         92
# 5         R. Lewandowski   28               Poland       91         91
# 6                 De Gea   26                Spain       90         92
# 7              E. Hazard   26              Belgium       90         91
# 8               T. Kroos   27              Germany       90         90
# 9             G. Higuaín   29            Argentina       90         90
# 10          Sergio Ramos   31                Spain       90         90
# 11          K. De Bruyne   26              Belgium       89         92
# ...

# %%
# Collect a list of all the unique values in "Preferred Position"
Soccer2018_df["Preferred Position"].unique()
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'CDM', 'CB', 'RM', 'CM', 'LM', 'LB', 'CAM',
#        'RB', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
# Looking only at strikers (ST) to start
strikers_2018_df = Soccer2018_df.loc[Soccer2018_df["Preferred Position"] == "ST", :]
strikers_2018_df.head()
# Out:
#                  Name  Age Nationality  Overall  Potential              Club  \
# 0   Cristiano Ronaldo   32    Portugal       94         94    Real Madrid CF
# 3           L. Suárez   30     Uruguay       92         92      FC Barcelona
# 5      R. Lewandowski   28      Poland       91         91  FC Bayern Munich
# 9          G. Higuaín   29   Argentina       90         90          Juventus
# 16          S. Agüero   29   Argentina       89         89   Manchester City
#
#    Preferred Position   CAM    CB   CDM  ...    RB   RCB   RCM   RDM    RF  \
# 0                  ST  89.0  53.0  62.0  ...  61.0  53.0  82.0  62.0  91.0
# 3                  ST  87.0  58.0  65.0  ...  64.0  58.0  80.0  65.0  88.0
# 5                  ST  84.0  57.0  62.0  ...  58.0  57.0  78.0  62.0  87.0
# 9                  ST  81.0  46.0  52.0  ...  51.0  46.0  71.0  52.0  84.0
# 16                 ST  85.0  44.0  54.0  ...  52.0  44.0  75.0  54.0  87.0
#
#       RM    RS    RW   RWB    ST
# ...

# %%
# Sort the DataFrame by the values in the "ST" column to find the worst
strikers_2018_df = strikers_2018_df.sort_values("ST", ascending=False)
strikers_2018_df
# Out:
#                    Name  Age          Nationality  Overall  Potential  \
# 2276  Cristiano Ronaldo   32             Portugal       94         94
# 2274     R. Lewandowski   28               Poland       91         91
# 2275          L. Suárez   30              Uruguay       92         92
# 2273         G. Higuaín   29            Argentina       90         90
# 2272          S. Agüero   29            Argentina       89         89
# 2271      P. Aubameyang   28                Gabon       88         88
# 2268          R. Lukaku   24              Belgium       86         90
# 2267            H. Kane   23              England       86         90
# 2269     Z. Ibrahimović   35               Sweden       88         88
# 2270          E. Cavani   30              Uruguay       87         87
# 2263       A. Lacazette   26               France       85         88
# 2261          T. Müller   27              Germany       86         86
# ...

# %%
# Reset the index so that the index is now based on the sorting locations
strikers_2018_df = strikers_2018_df.reset_index(drop=True)
strikers_2018_df.head()
# Out:
#              Name  Age Nationality  Overall  Potential                Club  \
# 0       L. Sackey   18       Ghana       46         64   Scunthorpe United
# 1        M. Zettl   18     Germany       50         67  SpVgg Unterhaching
# 2      O. Sowunmi   21     England       59         71         Yeovil Town
# 3  E. Mason-Clark   17     England       50         63              Barnet
# 4        J. Young   17    Scotland       46         61        Swindon Town
#
#   Preferred Position   CAM    CB   CDM  ...    RB   RCB   RCM   RDM    RF  \
# 0                 ST  29.0  45.0  38.0  ...  40.0  45.0  30.0  38.0  29.0
# 1                 ST  47.0  32.0  36.0  ...  39.0  32.0  42.0  36.0  46.0
# 2                 ST  35.0  58.0  47.0  ...  52.0  58.0  37.0  47.0  38.0
# 3                 ST  49.0  33.0  35.0  ...  39.0  33.0  42.0  35.0  49.0
# 4                 ST  44.0  28.0  29.0  ...  31.0  28.0  38.0  29.0  45.0
#
#      RM    RS    RW   RWB    ST
# 0  30.0  31.0  29.0  38.0  31.0
# ...

# %%
# Save all of the information collected on the worst striker
worst_striker = strikers_2018_df.loc[0, :]
worst_striker = strikers_2018_df.loc[len(strikers_2018_df)-1, :]
worst_striker
# Out:
# Name                          L. Sackey
# Age                                  18
# Nationality                       Ghana
# Overall                              46
# Potential                            64
# Club                  Scunthorpe United
# Preferred Position                   ST
# CAM                                  29
# CB                                   45
# CDM                                  38
# CF                                   29
# CM                                   30
# LAM                                  29
# LB                                   40
# LCB                                  45
# LCM                                  30
# LDM                                  38
# LF                                   29
# LM                                   30
# LS                                   31
# LW                                   29
# LWB                                  38
# RAM                                  29
# ...

# %%
# Import Dependencies
import pandas as pd

# %%
bitcoin_csv = "C:/Python/Bitcoin_cash_price.csv"
dash_csv = "C:/Python/dash_price.csv"

# %%
bitcoin_df = pd.read_csv(bitcoin_csv)
dash_df = pd.read_csv(dash_csv)

# %%
# Merge the two DataFrames together based on the Dates they share
crypto_df = pd.merge(bitcoin_df, dash_df, on="Date")
crypto_df.head()
# Out:
#         Date  Open_x  High_x   Low_x  Close_x   Volume_x   Market Cap_x  \
# 0  17-Sep-17  438.90  438.90  384.06   419.86  221828000  7,279,520,000
# 1  16-Sep-17  424.49  450.98  388.20   440.22  313583000  7,039,590,000
# 2  15-Sep-17  369.49  448.39  301.69   424.02  707231000  6,126,800,000
# 3  14-Sep-17  504.22  510.47  367.04   367.04  257431000  8,359,650,000
# 4  13-Sep-17  509.47  519.20  471.22   503.61  340344000  8,445,540,000
#
#    Open_y  High_y   Low_y  Close_y  Volume_y   Market Cap_y
# 0  298.59  315.58  278.17   313.84  38081600  2,257,850,000
# 1  284.50  301.23  276.57   298.86  43702600  2,150,800,000
# 2  236.05  300.11  220.51   284.36  72695500  1,784,040,000
# 3  301.11  303.74  236.24   236.24  35013800  2,275,100,000
# 4  324.72  325.16  287.25   301.29  28322500  2,452,930,000

# %%
bitcoin_df.head()
# Out:
#         Date    Open    High     Low   Close     Volume     Market Cap
# 0  17-Sep-17  438.90  438.90  384.06  419.86  221828000  7,279,520,000
# 1  16-Sep-17  424.49  450.98  388.20  440.22  313583000  7,039,590,000
# 2  15-Sep-17  369.49  448.39  301.69  424.02  707231000  6,126,800,000
# 3  14-Sep-17  504.22  510.47  367.04  367.04  257431000  8,359,650,000
# 4  13-Sep-17  509.47  519.20  471.22  503.61  340344000  8,445,540,000

# %%
dash_df.head()
# Out:
#         Date    Open    High     Low   Close    Volume     Market Cap
# 0  17-Sep-17  298.59  315.58  278.17  313.84  38081600  2,257,850,000
# 1  16-Sep-17  284.50  301.23  276.57  298.86  43702600  2,150,800,000
# 2  15-Sep-17  236.05  300.11  220.51  284.36  72695500  1,784,040,000
# 3  14-Sep-17  301.11  303.74  236.24  236.24  35013800  2,275,100,000
# 4  13-Sep-17  324.72  325.16  287.25  301.29  28322500  2,452,930,000

# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "C:/Python/Resources_ted_talks.csv"
ted_df = pd.read_csv(csv_path)
ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# ...

# %%
# Figure out the minimum and maximum views for a TED Talk
print(ted_df["views"].max())
print(ted_df["views"].min())

print(ted_df.max())
print(ted_df.min())
# Out:
# 47227110
# 50443
# comments                                                     6404
# description     “People are so afraid of variety that they try...
# duration                                                     5256
# event                                      World Science Festival
# languages                                                      72
# main_speaker                                    iO Tillett Wright
# name                       iO Tillett Wright: Fifty shades of gay
# title                            “Am I dying?” The honest answer.
# views                                                    47227110
# View Group                                           800k to 999k
# dtype: object
# comments                                                        2
# description     "A forest is much more than what you see," say...
# duration                                                      135
# event                                               AORN Congress
# ...

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 199999, 399999, 599999, 799999, 999999,
        1999999, 2999999, 3999999, 4999999, 50000000]

# Create labels for these bins
group_labels = ["0 to 199k", "200k to 399k", "400k to 599k", "600k to 799k", "800k to 999k", "1mil to 2mil",
                "2mil to 3mil", "3mil to 4mil", "4mil to 5mil", "5mil to 50mil"]

# %%
# Slice the data and place it into bins
df_g = pd.cut(ted_df["views"], bins, labels=group_labels).head()
df_g.head()
# Out:
# 0    5mil to 50mil
# 1     3mil to 4mil
# 2     1mil to 2mil
# 3     1mil to 2mil
# 4    5mil to 50mil
# Name: views, dtype: category
# Categories (10, object): [0 to 199k < 200k to 399k < 400k to 599k < 600k to 799k ... 2mil to 3mil < 3mil to 4mil < 4mil to 5mil < 5mil to 50mil]

# %%
# Place the data series into a new column inside of the DataFrame
#ted_df["View Group"] = pd.cut(ted_df["views"], bins, labels=group_labels)

ted_df["View Group"] = df_g

ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# ...

# %%
# Create a GroupBy object based upon "View Group"

ted_group = ted_df.groupby("View Group")
# Out:
# View Group

# %%
# Find how many rows fall into each bin
print(ted_group["View Group"].count())
# Out:
# View Group
# 0 to 199k          32
# 200k to 399k      135
# 400k to 599k      234
# 600k to 799k      307
# 800k to 999k      339
# 1mil to 2mil     1004
# 2mil to 3mil      239
# 3mil to 4mil       93
# 4mil to 5mil       68
# 5mil to 50mil      99
# Name: View Group, dtype: int64

# %%
# Get the average of each column within the GroupBy object
ted_group[["comments", "duration", "languages"]].mean()
# Out:
#                  comments    duration  languages
# View Group
# 0 to 199k       76.937500  898.187500   4.062500
# 200k to 399k    81.992593  832.192593  18.785185
# 400k to 599k   107.162393  870.517094  22.940171
# 600k to 799k   118.912052  829.039088  24.400651
# 800k to 999k   119.628319  798.772861  25.678466
# 1mil to 2mil   168.136454  809.899402  27.899402
# 2mil to 3mil   299.481172  832.430962  32.807531
# 3mil to 4mil   360.870968  809.505376  34.258065
# 4mil to 5mil   507.088235  920.514706  35.720588
# 5mil to 50mil  650.393939  884.282828  40.252525

# %%
#Kickstarter Project

# The path to our CSV file

# Read our Kickstarter data into pandas

# Get a list of all of our columns for easy reference


# Remove projects that made no money at all

# %%
#Kickstarter Project

# The path to our CSV file

import os
import pandas as pd

csv_path = "C:/Python/KickstarterData.csv"

kickstarter_df = pd.read_csv(csv_path)

# %%
#for i in enumerate(kickstarter_df.columns):
#    print("index:{} \tname:{}".format(i, name))

test_l =[4,7,2,9,4,10]

for i,num in enumerate(test_l):
    print("i: {}\tnum: {}".format(i,num))
# Out:
# i: 0	num: 4
# i: 1	num: 7
# i: 2	num: 2
# i: 3	num: 9
# i: 4	num: 4
# i: 5	num: 10

# %%
kickstarter_df.head()
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3  1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4   421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
# 3  9th International Meeting of Youth Theatre sap...
# 4                        Get Conti to the Ed Fringe!
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# ...

# %%
kickstarter_df.columns
# Out:
# Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'is_starrable', 'backers_count',
#        'static_usd_rate', 'usd_pledged', 'creator', 'location', 'category',
#        'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')

# %%
# Extract "name", "goal", "pledged", "state", "country", "staff_pick",
# "backers_count", and "spotlight"

reduced_kickstarter_df = kickstarter_df.loc[:, ["name", "goal", "pledged",
                                    "state", "country", "staff_pick", "backers_count", "spotlight"]]
reduced_kickstarter_df
# Out:
#                                                    name     goal   pledged  \
# 0     The Class Act Players Theatre Company Presents...   1500.0   2925.00
# 1     MR INCREDIBLE by Camilla Whitehill - VAULT Fes...   2500.0   2936.00
# 2                                                   RUN   1000.0   1200.00
# 3     9th International Meeting of Youth Theatre sap...   2000.0   2135.00
# 4                           Get Conti to the Ed Fringe!   1000.0   1250.00
# 5     Somebody Out There Loves Me @ Edinburgh Fringe...   1100.0   1100.00
# 6              Stand Up & Slam! at the Edinburgh Fringe   1500.0   1605.00
# 7          Edinburgh Fringe Tour of Two Modern Classics   2550.0   2552.00
# 8                               Forefront Festival 2015   7200.0   7230.00
# 9     Tangerine Theatre presents GODDESS by Serena H...   1200.0   1625.00
# 10                      I Would... get us to Edinburgh!    700.0    745.00
# ...

# %%
# Remove projects that made no money at all
reduced_kickstarter_df = reduced_kickstarter_df.loc[(
    reduced_kickstarter_df["pledged"] > 0)]
reduced_kickstarter_df.head()
# Out:
#                                                 name    goal  pledged  \
# 0  The Class Act Players Theatre Company Presents...  1500.0   2925.0
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...  2500.0   2936.0
# 2                                                RUN  1000.0   1200.0
# 3  9th International Meeting of Youth Theatre sap...  2000.0   2135.0
# 4                        Get Conti to the Ed Fringe!  1000.0   1250.0
#
#         state country  staff_pick  backers_count  spotlight
# 0  successful      US       False             17       True
# 1  successful      GB        True             15       True
# 2  successful      GB       False             30       True
# 3  successful      IT       False             24       True
# 4  successful      GB       False             28       True

# %%
# Collect only those projects that were hosted in the US.

# Create a list of the columns
columns = [
    "name", "goal", "pledged", "state", 
    "country", "staff_pick", "backers_count", "spotlight"]

#  Create a new df for "US" with the columns. 

hosted_in_us = reduced_kickstarter_df.loc[reduced_kickstarter_df["country"] == "US",  columns]
hosted_in_us.head()
# Out:
#                                                  name     goal  pledged  \
# 0   The Class Act Players Theatre Company Presents...   1500.0   2925.0
# 8                             Forefront Festival 2015   7200.0   7230.0
# 11                              Hamlet the Hip-Hopera   9747.0  10103.0
# 14                                          Pride Con  15000.0  15110.0
# 15      En Garde Arts Emerging Artists Festival BOSSS  10000.0  10306.0
#
#          state country  staff_pick  backers_count  spotlight
# 0   successful      US       False             17       True
# 8   successful      US       False             68       True
# 11  successful      US        True            132       True
# 14  successful      US       False             60       True
# 15  successful      US        True             80       True

# %%
# Create a new column that finds the average amount pledged to a project
average_donation = hosted_in_us['pledged'] / hosted_in_us['backers_count']
average_donation
# Out:
# 0       172.058824
# 8       106.323529
# 11       76.537879
# 14      251.833333
# 15      128.825000
# 17       66.578947
# 19       76.470588
# 20       61.666667
# 31      105.000000
# 32      143.181818
# 33       69.117647
# 39      167.117647
# 42       62.714286
# 43       81.975000
# 44       54.241935
# 45       65.216667
# 46       42.036765
# 47       99.131579
# 48       54.347826
# 50       93.147059
# 52       37.016129
# 54       90.130952
# 59      119.047619
# 64      229.772727
# 67       59.701493
# 73       27.133333
# 74       50.500000
# 75      106.358491
# 77       54.961165
# 79       44.426230
#            ...
# 4076    107.002075
# 4077     50.981818
# 4078     52.551020
# 4080     47.878788
# 4081    150.416667
# 4082     96.666667
# 4083    133.333333
# 4084     51.222222
# 4086     93.813433
# 4087    176.086957
# 4088     45.478261
# 4091     97.916667
# 4092     77.186047
# 4093     87.961538
# 4094    122.536585
# 4095     98.200000
# ...

# %%
# Create a new column that finds the average amount pledged to a project
average_donation = hosted_in_us['pledged'] / hosted_in_us['backers_count']
average_donation
# Out:
# 0       172.058824
# 8       106.323529
# 11       76.537879
# 14      251.833333
# 15      128.825000
# 17       66.578947
# 19       76.470588
# 20       61.666667
# 31      105.000000
# 32      143.181818
# 33       69.117647
# 39      167.117647
# 42       62.714286
# 43       81.975000
# 44       54.241935
# 45       65.216667
# 46       42.036765
# 47       99.131579
# 48       54.347826
# 50       93.147059
# 52       37.016129
# 54       90.130952
# 59      119.047619
# 64      229.772727
# 67       59.701493
# 73       27.133333
# 74       50.500000
# 75      106.358491
# 77       54.961165
# 79       44.426230
#            ...
# 4076    107.002075
# 4077     50.981818
# 4078     52.551020
# 4080     47.878788
# 4081    150.416667
# 4082     96.666667
# 4083    133.333333
# 4084     51.222222
# 4086     93.813433
# 4087    176.086957
# 4088     45.478261
# 4091     97.916667
# 4092     77.186047
# 4093     87.961538
# 4094    122.536585
# 4095     98.200000
# ...

# %%
# Calculate the total number of backers for all US projects
hosted_in_us["backers_count"].sum()
# Out:
# 89273

# %%
# Calculate the average number of backers for all US projects
hosted_in_us["backers_count"].mean()
# Out:
# 41.931892907468296

# %%
 # Collect only those US campaigns that have been picked as a "Staff Pick"
picked_by_staff = hosted_in_us.loc[hosted_in_us["staff_pick"] == True]
picked_by_staff
# Out:
#                                                    name      goal    pledged  \
# 11                                Hamlet the Hip-Hopera    9747.0   10103.00
# 15        En Garde Arts Emerging Artists Festival BOSSS   10000.0   10306.00
# 39                      "Poor People" at FringeNYC 2015    5500.0    5682.00
# 44     Queen Mab's Steampunk and Fairie Street Festival    1300.0    3363.00
# 45                   RAFT: a new play by Emily Kitchens    7500.0    7826.00
# 47    The Spinning Wheel: a son remixes a father's r...   20000.0   22602.00
# 50                     Bloomers Presents: LaughtHERfest    8000.0    9501.00
# 54    Natasha Noman's Noman's Land  | Aug 5-15th Edi...    7000.0    7571.00
# 107   Peter/Wendy goes to the 2015 Edinburgh Fringe ...   10000.0   12003.00
# 115         La Lune de Femme goes to New Orleans Fringe    5000.0    5519.00
# 117                               Secular Solstice 2014    7500.0    8157.01
# ...

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"
picked_by_staff = hosted_in_us.loc[hosted_in_us["staff_pick"] == True]
picked_by_staff
# Out:
#                                                    name      goal    pledged  \
# 11                                Hamlet the Hip-Hopera    9747.0   10103.00
# 15        En Garde Arts Emerging Artists Festival BOSSS   10000.0   10306.00
# 39                      "Poor People" at FringeNYC 2015    5500.0    5682.00
# 44     Queen Mab's Steampunk and Fairie Street Festival    1300.0    3363.00
# 45                   RAFT: a new play by Emily Kitchens    7500.0    7826.00
# 47    The Spinning Wheel: a son remixes a father's r...   20000.0   22602.00
# 50                     Bloomers Presents: LaughtHERfest    8000.0    9501.00
# 54    Natasha Noman's Noman's Land  | Aug 5-15th Edi...    7000.0    7571.00
# 107   Peter/Wendy goes to the 2015 Edinburgh Fringe ...   10000.0   12003.00
# 115         La Lune de Femme goes to New Orleans Fringe    5000.0    5519.00
# 117                               Secular Solstice 2014    7500.0    8157.01
# ...

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"
picked_by_staff = hosted_in_us.loc[hosted_in_us["staff_pick"] == True]
picked_by_staff
