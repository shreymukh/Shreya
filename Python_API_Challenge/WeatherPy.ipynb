# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | kloulklubed
# Processing Record 7 of Set 1 | isiro
# Processing Record 8 of Set 1 | ouango
# Processing Record 9 of Set 1 | trairi
# Processing Record 10 of Set 1 | beringovskiy
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | dickinson
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | port hardy
# Processing Record 15 of Set 1 | yeniseysk
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | hammerfest
# Processing Record 18 of Set 1 | bourges
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | cordele
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | yar-sale
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | padang
# Processing Record 30 of Set 1 | alyangula
# Processing Record 31 of Set 1 | rocha
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | saint john
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | paptalaya
# Processing Record 40 of Set 1 | sampit
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | saint-pierre
# Processing Record 43 of Set 1 | baft
# Processing Record 44 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 1 | cabo san lucas
# Processing Record 46 of Set 1 | pueblo bello
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | lucapa
# Processing Record 0 of Set 2 | baculin
# Processing Record 1 of Set 2 | sinegorye
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | port augusta
# Processing Record 5 of Set 2 | zhigansk
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | lasa
# Processing Record 8 of Set 2 | yatou
# Processing Record 9 of Set 2 | quesnel
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | asau
# City not found. Skipping...
# Processing Record 13 of Set 2 | richards bay
# Processing Record 14 of Set 2 | palaiokhora
# City not found. Skipping...
# Processing Record 15 of Set 2 | krasnoshchekovo
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 2 | oskarshamn
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | biloela
# Processing Record 24 of Set 2 | honningsvag
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | cidreira
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | samarai
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | karratha
# Processing Record 35 of Set 2 | itoman
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | kabalo
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | gamba
# Processing Record 43 of Set 2 | miandrivazo
# Processing Record 44 of Set 2 | harindanga
# Processing Record 45 of Set 2 | kisangani
# Processing Record 46 of Set 2 | rameswaram
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 49 of Set 2 | kavaratti
# Processing Record 0 of Set 3 | vardo
# Processing Record 1 of Set 3 | seoul
# Processing Record 2 of Set 3 | mehamn
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | kamenka
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | san vicente
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | malynivka
# Processing Record 11 of Set 3 | kununurra
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | villa carlos paz
# Processing Record 14 of Set 3 | axim
# Processing Record 15 of Set 3 | boda
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | ashland
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | praya
# Processing Record 23 of Set 3 | njeru
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | ust-karsk
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | rio gallegos
# Processing Record 30 of Set 3 | lujan
# Processing Record 31 of Set 3 | mombetsu
# Processing Record 32 of Set 3 | palmer
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | touros
# Processing Record 35 of Set 3 | tiznit
# Processing Record 36 of Set 3 | san jose
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | luangwa
# Processing Record 39 of Set 3 | saint-augustin
# Processing Record 40 of Set 3 | oyama
# Processing Record 41 of Set 3 | vung tau
# Processing Record 42 of Set 3 | pandhana
# Processing Record 43 of Set 3 | guerrero negro
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | odienne
# Processing Record 46 of Set 3 | lata
# Processing Record 47 of Set 3 | conde
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 0 of Set 4 | east london
# Processing Record 1 of Set 4 | plettenberg bay
# Processing Record 2 of Set 4 | kerouane
# Processing Record 3 of Set 4 | twin falls
# Processing Record 4 of Set 4 | chitipa
# Processing Record 5 of Set 4 | portree
# Processing Record 6 of Set 4 | baghdad
# Processing Record 7 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 4 | bulgan
# Processing Record 9 of Set 4 | ambagarh chauki
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | khurai
# Processing Record 12 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | alta floresta
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | kuandian
# Processing Record 20 of Set 4 | albanel
# Processing Record 21 of Set 4 | katangli
# Processing Record 22 of Set 4 | quatre cocos
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | sabha
# Processing Record 25 of Set 4 | malanje
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | santiago
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | kletnya
# Processing Record 30 of Set 4 | pauini
# Processing Record 31 of Set 4 | san lorenzo
# Processing Record 32 of Set 4 | beloha
# Processing Record 33 of Set 4 | north bend
# Processing Record 34 of Set 4 | kismayo
# City not found. Skipping...
# Processing Record 35 of Set 4 | azul
# Processing Record 36 of Set 4 | luanda
# Processing Record 37 of Set 4 | barstow
# Processing Record 38 of Set 4 | yilan
# Processing Record 39 of Set 4 | grand gaube
# Processing Record 40 of Set 4 | acapulco
# Processing Record 41 of Set 4 | morro bay
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | ngunguru
# Processing Record 44 of Set 4 | claudio
# Processing Record 45 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | bilma
# Processing Record 48 of Set 4 | grindavik
# Processing Record 49 of Set 4 | tuy hoa
# Processing Record 0 of Set 5 | yermakovskoye
# Processing Record 1 of Set 5 | puerto leguizamo
# Processing Record 2 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 3 of Set 5 | marawi
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | araxa
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 5 | agadir
# Processing Record 9 of Set 5 | wanlaweyn
# Processing Record 10 of Set 5 | belle glade
# Processing Record 11 of Set 5 | victor harbor
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | arlit
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | tommot
# Processing Record 18 of Set 5 | nicoya
# Processing Record 19 of Set 5 | clyde river
# Processing Record 20 of Set 5 | dongsheng
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | inhambane
# Processing Record 23 of Set 5 | aksay
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | bardiyah
# City not found. Skipping...
# Processing Record 28 of Set 5 | bac lieu
# City not found. Skipping...
# Processing Record 29 of Set 5 | mangai
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | champerico
# Processing Record 33 of Set 5 | sao joao da barra
# Processing Record 34 of Set 5 | glens falls
# Processing Record 35 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 36 of Set 5 | ranong
# Processing Record 37 of Set 5 | hobyo
# Processing Record 38 of Set 5 | victoria
# Processing Record 39 of Set 5 | aykhal
# Processing Record 40 of Set 5 | otjimbingwe
# Processing Record 41 of Set 5 | mingguang
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 5 | boyolangu
# Processing Record 45 of Set 5 | teya
# Processing Record 46 of Set 5 | iranshahr
# Processing Record 47 of Set 5 | norman wells
# Processing Record 48 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 0 of Set 6 | odessa
# Processing Record 1 of Set 6 | kaeo
# Processing Record 2 of Set 6 | rudbar
# City not found. Skipping...
# Processing Record 3 of Set 6 | hakui
# Processing Record 4 of Set 6 | surin
# Processing Record 5 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 6 | cacoal
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | campbell river
# Processing Record 9 of Set 6 | russell
# Processing Record 10 of Set 6 | diffa
# Processing Record 11 of Set 6 | plymouth
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | makakilo city
# Processing Record 14 of Set 6 | ayacucho
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | sydney
# Processing Record 17 of Set 6 | pascagoula
# Processing Record 18 of Set 6 | coihaique
# Processing Record 19 of Set 6 | lebork
# Processing Record 20 of Set 6 | kingisepp
# Processing Record 21 of Set 6 | puerto montt
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | avera
# Processing Record 24 of Set 6 | barrancas
# Processing Record 25 of Set 6 | gornopravdinsk
# Processing Record 26 of Set 6 | sao gabriel da cachoeira
# Processing Record 27 of Set 6 | zhezkazgan
# Processing Record 28 of Set 6 | ippy
# Processing Record 29 of Set 6 | mandalgovi
# Processing Record 30 of Set 6 | portland
# Processing Record 31 of Set 6 | xinzhi
# Processing Record 32 of Set 6 | hirara
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | new haven
# Processing Record 36 of Set 6 | balao
# Processing Record 37 of Set 6 | odder
# Processing Record 38 of Set 6 | ishigaki
# Processing Record 39 of Set 6 | adrar
# Processing Record 40 of Set 6 | dunedin
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | brae
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | skovorodino
# Processing Record 45 of Set 6 | voi
# Processing Record 46 of Set 6 | chippewa falls
# Processing Record 47 of Set 6 | sitamau
# Processing Record 48 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 49 of Set 6 | gat
# Processing Record 0 of Set 7 | khatanga
# Processing Record 1 of Set 7 | kilindoni
# Processing Record 2 of Set 7 | cabedelo
# Processing Record 3 of Set 7 | klaksvik
# Processing Record 4 of Set 7 | buenos aires
# Processing Record 5 of Set 7 | omboue
# Processing Record 6 of Set 7 | lavrentiya
# Processing Record 7 of Set 7 | port hedland
# Processing Record 8 of Set 7 | olga
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | candelaria
# Processing Record 11 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 12 of Set 7 | luziania
# Processing Record 13 of Set 7 | necochea
# Processing Record 14 of Set 7 | vanimo
# Processing Record 15 of Set 7 | erzin
# Processing Record 16 of Set 7 | the valley
# Processing Record 17 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 18 of Set 7 | dukat
# Processing Record 19 of Set 7 | tessalit
# Processing Record 20 of Set 7 | quballat
# Processing Record 21 of Set 7 | uaua
# Processing Record 22 of Set 7 | benguela
# Processing Record 23 of Set 7 | panama city
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | eisiskes
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | korla
# City not found. Skipping...
# Processing Record 29 of Set 7 | mayo
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | usinsk
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | wajima
# Processing Record 34 of Set 7 | haines junction
# Processing Record 35 of Set 7 | aviles
# Processing Record 36 of Set 7 | amontada
# Processing Record 37 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 7 | lahaina
# Processing Record 40 of Set 7 | saint-joseph
# Processing Record 41 of Set 7 | husavik
# Processing Record 42 of Set 7 | padalarang
# Processing Record 43 of Set 7 | talcahuano
# Processing Record 44 of Set 7 | nizhniy baskunchak
# Processing Record 45 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 7 | daloa
# Processing Record 47 of Set 7 | takoradi
# Processing Record 48 of Set 7 | tura
# Processing Record 49 of Set 7 | illela
# Processing Record 0 of Set 8 | vikindu
# Processing Record 1 of Set 8 | santa isabel do rio negro
# Processing Record 2 of Set 8 | tiarei
# Processing Record 3 of Set 8 | hearst
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | comodoro rivadavia
# Processing Record 6 of Set 8 | zaranj
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | townsville
# Processing Record 9 of Set 8 | chara
# Processing Record 10 of Set 8 | fairbanks
# Processing Record 11 of Set 8 | marsh harbour
# Processing Record 12 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 8 | anadyr
# Processing Record 14 of Set 8 | tukrah
# City not found. Skipping...
# Processing Record 15 of Set 8 | grootfontein
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | coquimbo
# Processing Record 19 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | sorland
# Processing Record 21 of Set 8 | zhicheng
# Processing Record 22 of Set 8 | emerald
# Processing Record 23 of Set 8 | itupiranga
# Processing Record 24 of Set 8 | tres arroyos
# Processing Record 25 of Set 8 | sao filipe
# Processing Record 26 of Set 8 | sao miguel do araguaia
# Processing Record 27 of Set 8 | cutro
# Processing Record 28 of Set 8 | yen bai
# Processing Record 29 of Set 8 | haikou
# Processing Record 30 of Set 8 | damghan
# Processing Record 31 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 8 | srednekolymsk
# Processing Record 33 of Set 8 | atambua
# Processing Record 34 of Set 8 | haicheng
# Processing Record 35 of Set 8 | riyadh
# Processing Record 36 of Set 8 | correntina
# Processing Record 37 of Set 8 | ulladulla
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | pathein
# Processing Record 40 of Set 8 | tucuman
# Processing Record 41 of Set 8 | sisimiut
# Processing Record 42 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 8 | jimo
# Processing Record 44 of Set 8 | rio grande
# Processing Record 45 of Set 8 | namatanai
# Processing Record 46 of Set 8 | mezen
# Processing Record 47 of Set 8 | capiibary
# Processing Record 48 of Set 8 | shaikhpura
# Processing Record 49 of Set 8 | nagapattinam
# Processing Record 0 of Set 9 | churapcha
# Processing Record 1 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | alice springs
# Processing Record 4 of Set 9 | siniscola
# Processing Record 5 of Set 9 | magadan
# Processing Record 6 of Set 9 | etchoropo
# Processing Record 7 of Set 9 | port blair
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | bathsheba
# Processing Record 10 of Set 9 | awjilah
# Processing Record 11 of Set 9 | kavieng
# Processing Record 12 of Set 9 | liberal
# Processing Record 13 of Set 9 | ammon
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | okha
# Processing Record 16 of Set 9 | camacha
# Processing Record 17 of Set 9 | pangnirtung
# Processing Record 18 of Set 9 | taltal
# Processing Record 19 of Set 9 | nakasongola
# Processing Record 20 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 9 | bria
# Processing Record 22 of Set 9 | mwense
# Processing Record 23 of Set 9 | wageningen
# Processing Record 24 of Set 9 | dwarka
# Processing Record 25 of Set 9 | ust-nera
# Processing Record 26 of Set 9 | chaochou
# City not found. Skipping...
# Processing Record 27 of Set 9 | burica
# City not found. Skipping...
# Processing Record 28 of Set 9 | batagay
# Processing Record 29 of Set 9 | trinidad
# Processing Record 30 of Set 9 | novonikolayevskiy
# Processing Record 31 of Set 9 | villanueva
# Processing Record 32 of Set 9 | savelugu
# Processing Record 33 of Set 9 | karuzi
# Processing Record 34 of Set 9 | kieta
# Processing Record 35 of Set 9 | serenje
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | buraydah
# Processing Record 38 of Set 9 | maputo
# Processing Record 39 of Set 9 | port-cartier
# Processing Record 40 of Set 9 | manokwari
# Processing Record 41 of Set 9 | college
# Processing Record 42 of Set 9 | severobaykalsk
# Processing Record 43 of Set 9 | fort nelson
# Processing Record 44 of Set 9 | isla mujeres
# Processing Record 45 of Set 9 | turukhansk
# Processing Record 46 of Set 9 | mount gambier
# Processing Record 47 of Set 9 | carutapera
# Processing Record 48 of Set 9 | kalmar
# Processing Record 49 of Set 9 | abu dhabi
# Processing Record 0 of Set 10 | berbera
# City not found. Skipping...
# Processing Record 1 of Set 10 | kampot
# Processing Record 2 of Set 10 | nenjiang
# Processing Record 3 of Set 10 | shirokiy
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | noyabrsk
# Processing Record 6 of Set 10 | oranjemund
# Processing Record 7 of Set 10 | svetlaya
# Processing Record 8 of Set 10 | demerval lobao
# Processing Record 9 of Set 10 | imeni poliny osipenko
# Processing Record 10 of Set 10 | gizo
# Processing Record 11 of Set 10 | sola
# Processing Record 12 of Set 10 | igrim
# Processing Record 13 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 10 | toyooka
# Processing Record 15 of Set 10 | jacareacanga
# Processing Record 16 of Set 10 | morgan city
# Processing Record 17 of Set 10 | port-gentil
# Processing Record 18 of Set 10 | seymchan
# Processing Record 19 of Set 10 | boralday
# Processing Record 20 of Set 10 | kachiry
# Processing Record 21 of Set 10 | aswan
# Processing Record 22 of Set 10 | kihei
# Processing Record 23 of Set 10 | araceli
# Processing Record 24 of Set 10 | riacho de santana
# Processing Record 25 of Set 10 | severo-yeniseyskiy
# Processing Record 26 of Set 10 | nortelandia
# Processing Record 27 of Set 10 | atasu
# Processing Record 28 of Set 10 | kulhudhuffushi
# Processing Record 29 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 10 | kaohsiung
# Processing Record 31 of Set 10 | pangody
# Processing Record 32 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 10 | yangambi
# Processing Record 34 of Set 10 | jaguaribe
# Processing Record 35 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 10 | hanna
# Processing Record 37 of Set 10 | kemin
# Processing Record 38 of Set 10 | ginda
# Processing Record 39 of Set 10 | tervel
# Processing Record 40 of Set 10 | ogaminana
# Processing Record 41 of Set 10 | yulara
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | kiruna
# Processing Record 44 of Set 10 | toropets
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | mooresville
# Processing Record 47 of Set 10 | bada
# Processing Record 48 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 10 | rimbey
# Processing Record 0 of Set 11 | abu samrah
# Processing Record 1 of Set 11 | wahiawa
# Processing Record 2 of Set 11 | joshimath
# Processing Record 3 of Set 11 | ormara
# Processing Record 4 of Set 11 | ape
# Processing Record 5 of Set 11 | cochrane
# Processing Record 6 of Set 11 | mantua
# Processing Record 7 of Set 11 | williams lake
# Processing Record 8 of Set 11 | fortuna
# Processing Record 9 of Set 11 | sunel
# Processing Record 10 of Set 11 | lagunas
# Processing Record 11 of Set 11 | linjiang
# Processing Record 12 of Set 11 | parras
# City not found. Skipping...
# Processing Record 13 of Set 11 | moses lake
# Processing Record 14 of Set 11 | mackenzie
# Processing Record 15 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 16 of Set 11 | codrington
# Processing Record 17 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 11 | mabaruma
# Processing Record 19 of Set 11 | nizhniy tsasuchey
# Processing Record 20 of Set 11 | vikhorevka
# Processing Record 21 of Set 11 | sao jose da coroa grande
# Processing Record 22 of Set 11 | nhulunbuy
# Processing Record 23 of Set 11 | waipawa
# Processing Record 24 of Set 11 | dogondoutchi
# Processing Record 25 of Set 11 | bonavista
# Processing Record 26 of Set 11 | nefteyugansk
# Processing Record 27 of Set 11 | pangai
# Processing Record 28 of Set 11 | diphu
# Processing Record 29 of Set 11 | malanville
# Processing Record 30 of Set 11 | pontianak
# Processing Record 31 of Set 11 | rosarito
# Processing Record 32 of Set 11 | weligama
# Processing Record 33 of Set 11 | ukhta
# Processing Record 34 of Set 11 | voyvozh
# Processing Record 35 of Set 11 | gondar
# Processing Record 36 of Set 11 | saint anthony
# Processing Record 37 of Set 11 | ola
# Processing Record 38 of Set 11 | kahului
# Processing Record 39 of Set 11 | banikoara
# Processing Record 40 of Set 11 | antanifotsy
# Processing Record 41 of Set 11 | miramar
# Processing Record 42 of Set 11 | kidal
# Processing Record 43 of Set 11 | ahipara
# Processing Record 44 of Set 11 | vao
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | airai
# Processing Record 47 of Set 11 | soyo
# Processing Record 48 of Set 11 | digha
# Processing Record 49 of Set 11 | yashkul
# Processing Record 0 of Set 12 | malakal
# City not found. Skipping...
# Processing Record 1 of Set 12 | kiboga
# Processing Record 2 of Set 12 | cap malheureux
# Processing Record 3 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 4 of Set 12 | betafo
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | kruisfontein
# Processing Record 7 of Set 12 | cartagena
# Processing Record 8 of Set 12 | kushiro
# Processing Record 9 of Set 12 | pitimbu
# Processing Record 10 of Set 12 | vila
# Processing Record 11 of Set 12 | prince rupert
# Processing Record 12 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 12 | manaure
# Processing Record 14 of Set 12 | lircay
# Processing Record 15 of Set 12 | galveston
# Processing Record 16 of Set 12 | loiza
# Processing Record 17 of Set 12 | roebourne
# Processing Record 18 of Set 12 | juneau
# Processing Record 19 of Set 12 | oron
# Processing Record 20 of Set 12 | payson
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | noumea
# Processing Record 23 of Set 12 | belaya gora
# Processing Record 24 of Set 12 | san ramon de la nueva oran
# Processing Record 25 of Set 12 | popondetta
# Processing Record 26 of Set 12 | ixtapa
# Processing Record 27 of Set 12 | san cristobal
# Processing Record 28 of Set 12 | marsa matruh
# Processing Record 29 of Set 12 | pisco
# Processing Record 30 of Set 12 | esmeraldas
# Processing Record 31 of Set 12 | dudinka
# Processing Record 32 of Set 12 | kaka
# Processing Record 33 of Set 12 | swift current
# Processing Record 34 of Set 12 | yantai
# Processing Record 35 of Set 12 | lauria
# Processing Record 36 of Set 12 | tromso
# Processing Record 37 of Set 12 | camana
# City not found. Skipping...
# Processing Record 38 of Set 12 | narsaq
# Processing Record 39 of Set 12 | north platte
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | vila franca do campo
# Processing Record 42 of Set 12 | salalah
# Processing Record 43 of Set 12 | garissa
# Processing Record 44 of Set 12 | sayyan
# Processing Record 45 of Set 12 | watertown
# Processing Record 46 of Set 12 | peno
# Processing Record 47 of Set 12 | mayumba
# Processing Record 48 of Set 12 | vanavara
# Processing Record 49 of Set 12 | krasne
# Processing Record 0 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | montemor-o-novo
# Processing Record 2 of Set 13 | shingu
# Processing Record 3 of Set 13 | corning
# Processing Record 4 of Set 13 | toba
# Processing Record 5 of Set 13 | nisia floresta
# Processing Record 6 of Set 13 | sandnessjoen
# Processing Record 7 of Set 13 | ampanihy
# Processing Record 8 of Set 13 | perelyub
# Processing Record 9 of Set 13 | constitucion
# Processing Record 10 of Set 13 | varena
# Processing Record 11 of Set 13 | marystown
# Processing Record 12 of Set 13 | janakpur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          tiksi          76      RU  1572936027        94  71.64  128.87
# 1  mar del plata          21      AR  1572936027        45 -46.43  -67.52
# 2        ushuaia          90      AR  1572936027        80 -54.81  -68.31
# 3           hilo          40      US  1572936027        78  19.71 -155.08
# 4    kloulklubed          90      PW  1572936027        88   7.04  134.26
#
#    Max Temp  Wind Speed
# 0    -12.11        2.84
# 1     51.17       41.56
# 2     39.20       10.29
# 3     78.80        4.70
# 4     78.80       18.34

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig4.png")

# Show plot
plt.show()
