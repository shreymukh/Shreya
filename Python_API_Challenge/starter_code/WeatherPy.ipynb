# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/17703/Desktop/Shreya/Python_API_Challenge/starter_code/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 264

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | sioux lookout
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | luderitz
# Processing Record 5 of Set 1 | ajdabiya
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | singleton
# Processing Record 16 of Set 1 | xining
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | kaliua
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | salinopolis
# Processing Record 26 of Set 1 | grand gaube
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | sinnamary
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | alyangula
# Processing Record 33 of Set 1 | praia da vitoria
# Processing Record 34 of Set 1 | sa kaeo
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | nanortalik
# Processing Record 38 of Set 1 | anuradhapura
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | beyneu
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | soure
# Processing Record 43 of Set 1 | umm lajj
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | along
# Processing Record 46 of Set 1 | smidovich
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | nemuro
# Processing Record 49 of Set 1 | kumano
# Processing Record 50 of Set 1 | port alfred
# Processing Record 0 of Set 2 | katherine
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | hofn
# Processing Record 3 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 2 | macusani
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | atar
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | vagur
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | zhongshan
# Processing Record 24 of Set 2 | kirakira
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | onverwacht
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | mahanoro
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | bonthe
# Processing Record 31 of Set 2 | labuhan
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | likhoslavl
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | krasnoselkup
# City not found. Skipping...
# Processing Record 39 of Set 2 | port pirie
# Processing Record 40 of Set 2 | asheboro
# Processing Record 41 of Set 2 | grindavik
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | wanning
# Processing Record 44 of Set 2 | korem
# Processing Record 45 of Set 2 | nome
# Processing Record 46 of Set 2 | goderich
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | namibe
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 0 of Set 3 | georgetown
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | merritt
# Processing Record 4 of Set 3 | alamosa
# Processing Record 5 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 3 | lasa
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | zonguldak
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | uch
# Processing Record 12 of Set 3 | presidencia roque saenz pena
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | yandoon
# City not found. Skipping...
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | bairiki
# City not found. Skipping...
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | gamba
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | ponnani
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | xai-xai
# Processing Record 25 of Set 3 | el dorado
# Processing Record 26 of Set 3 | alpena
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 3 | myrtle beach
# Processing Record 30 of Set 3 | pacifica
# Processing Record 31 of Set 3 | lukow
# Processing Record 32 of Set 3 | ambilobe
# Processing Record 33 of Set 3 | buraydah
# Processing Record 34 of Set 3 | beroroha
# Processing Record 35 of Set 3 | necochea
# Processing Record 36 of Set 3 | isabela
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | shahrud
# Processing Record 39 of Set 3 | jumla
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | madras
# Processing Record 44 of Set 3 | bilma
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | deputatskiy
# Processing Record 49 of Set 3 | sire
# Processing Record 0 of Set 4 | sulphur springs
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | santa maria
# Processing Record 3 of Set 4 | andenes
# City not found. Skipping...
# Processing Record 4 of Set 4 | fairbanks
# Processing Record 5 of Set 4 | dongsheng
# Processing Record 6 of Set 4 | egvekinot
# Processing Record 7 of Set 4 | wanaka
# Processing Record 8 of Set 4 | serebryansk
# Processing Record 9 of Set 4 | tommot
# Processing Record 10 of Set 4 | cairo
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | ulaangom
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | shu
# Processing Record 15 of Set 4 | poya
# Processing Record 16 of Set 4 | outjo
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 4 | lang son
# Processing Record 21 of Set 4 | haines junction
# Processing Record 22 of Set 4 | inhambane
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | san jose
# Processing Record 26 of Set 4 | nantucket
# Processing Record 27 of Set 4 | pacific grove
# Processing Record 28 of Set 4 | glenwood springs
# Processing Record 29 of Set 4 | belmonte
# Processing Record 30 of Set 4 | mapiri
# Processing Record 31 of Set 4 | aksay
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | marion
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | banes
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | sur
# Processing Record 39 of Set 4 | port-gentil
# Processing Record 40 of Set 4 | peace river
# Processing Record 41 of Set 4 | jinxiang
# Processing Record 42 of Set 4 | mokhsogollokh
# Processing Record 43 of Set 4 | erdenet
# Processing Record 44 of Set 4 | nouakchott
# Processing Record 45 of Set 4 | boende
# Processing Record 46 of Set 4 | syamzha
# Processing Record 47 of Set 4 | ambunti
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | anori
# Processing Record 0 of Set 5 | el alto
# Processing Record 1 of Set 5 | luganville
# Processing Record 2 of Set 5 | palmer
# Processing Record 3 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 5 | cap malheureux
# Processing Record 5 of Set 5 | clermont
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | stornoway
# City not found. Skipping...
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | kopayhorod
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | manaure
# Processing Record 13 of Set 5 | lima
# Processing Record 14 of Set 5 | harper
# Processing Record 15 of Set 5 | mahajanga
# Processing Record 16 of Set 5 | vardo
# Processing Record 17 of Set 5 | kirkland lake
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | umuarama
# Processing Record 21 of Set 5 | radcliff
# Processing Record 22 of Set 5 | kupino
# Processing Record 23 of Set 5 | san jose iturbide
# Processing Record 24 of Set 5 | mount isa
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | mackay
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | bac lieu
# City not found. Skipping...
# Processing Record 30 of Set 5 | otane
# Processing Record 31 of Set 5 | flinders
# Processing Record 32 of Set 5 | bellavista
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | dubrovnik
# Processing Record 35 of Set 5 | sungaipenuh
# Processing Record 36 of Set 5 | tigil
# Processing Record 37 of Set 5 | turukhansk
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | boras
# Processing Record 40 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 41 of Set 5 | nuevo progreso
# Processing Record 42 of Set 5 | sechura
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | rudbar
# City not found. Skipping...
# Processing Record 45 of Set 5 | monduli
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | airai
# Processing Record 48 of Set 5 | karoi
# Processing Record 49 of Set 5 | chabahar
# Processing Record 0 of Set 6 | reconquista
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | viedma
# Processing Record 3 of Set 6 | daru
# Processing Record 4 of Set 6 | jalu
# Processing Record 5 of Set 6 | solsona
# Processing Record 6 of Set 6 | annau
# Processing Record 7 of Set 6 | maceio
# Processing Record 8 of Set 6 | kavieng
# Processing Record 9 of Set 6 | bastia
# Processing Record 10 of Set 6 | biak
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | tuban
# Processing Record 13 of Set 6 | saldanha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          239
# Cloudiness    239
# Country       239
# Date          239
# Humidity      239
# Lat           239
# Lng           239
# Max Temp      239
# Wind Speed    239
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      busselton           0      AU  1574914678        21 -33.64  115.35
# 1  sioux lookout          90      CA  1574914380        85  50.10  -91.92
# 2      saskylakh          99      RU  1574914678        90  71.97  114.09
# 3       luderitz           0      NA  1574914678        83 -26.65   15.16
# 4       ajdabiya           1      LY  1574914678        81  30.75   20.22
#
#    Max Temp  Wind Speed
# 0     77.00       10.60
# 1     17.60        5.82
# 2      2.97       15.66
# 3     61.81       12.44
# 4     59.99        3.78

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", color = "magenta", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(False)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya/Python_API_Challenge/starter_code/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", color ="cyan", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(False)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya/Python_API_Challenge/starter_code/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", color = "red", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(False)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya/Python_API_Challenge/starter_code/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", color ="green", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(False)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya/Python_API_Challenge/starter_code/Fig4.png")

# Show plot
plt.show()
