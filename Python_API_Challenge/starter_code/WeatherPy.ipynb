# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | chabahar
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | half moon bay
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | ponta delgada
# Processing Record 21 of Set 1 | coihaique
# Processing Record 22 of Set 1 | kearney
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | lakatoro
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | nicoya
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | maragogi
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | noumea
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | tagusao
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | bubaque
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | penalva
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | palauig
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | labrea
# City not found. Skipping...
# Processing Record 49 of Set 1 | srednekolymsk
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 0 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 2 | santiago
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | port macquarie
# Processing Record 6 of Set 2 | ilhabela
# Processing Record 7 of Set 2 | samoded
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | khasan
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | kulu
# Processing Record 14 of Set 2 | jumla
# Processing Record 15 of Set 2 | grootfontein
# Processing Record 16 of Set 2 | fort nelson
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | hami
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | san jose
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | juneau
# Processing Record 26 of Set 2 | haines junction
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | barranca
# Processing Record 29 of Set 2 | rawson
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | jiuquan
# Processing Record 32 of Set 2 | shahrud
# Processing Record 33 of Set 2 | kaliganj
# Processing Record 34 of Set 2 | hope
# Processing Record 35 of Set 2 | krasnoselkup
# City not found. Skipping...
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | lianzhou
# Processing Record 38 of Set 2 | jacala
# Processing Record 39 of Set 2 | palmer
# Processing Record 40 of Set 2 | vostok
# Processing Record 41 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 42 of Set 2 | itupiranga
# Processing Record 43 of Set 2 | ossora
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | sisimiut
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | ritchie
# Processing Record 0 of Set 3 | virginia beach
# Processing Record 1 of Set 3 | zeya
# Processing Record 2 of Set 3 | scarborough
# Processing Record 3 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 3 | aasiaat
# Processing Record 5 of Set 3 | waingapu
# Processing Record 6 of Set 3 | kidal
# Processing Record 7 of Set 3 | adrar
# Processing Record 8 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 3 | leningradskiy
# Processing Record 10 of Set 3 | matara
# Processing Record 11 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 3 | wrexham
# Processing Record 13 of Set 3 | kamenka
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | punta alta
# Processing Record 16 of Set 3 | ruginoasa
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | sept-iles
# Processing Record 20 of Set 3 | college
# Processing Record 21 of Set 3 | san pedro
# Processing Record 22 of Set 3 | ust-nera
# Processing Record 23 of Set 3 | guadalupe victoria
# Processing Record 24 of Set 3 | aklavik
# Processing Record 25 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 3 | bislig
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | makakilo city
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | villamaria
# Processing Record 33 of Set 3 | puteyets
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | beringovskiy
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | parabel
# Processing Record 40 of Set 3 | thompson
# Processing Record 41 of Set 3 | albany
# Processing Record 42 of Set 3 | kerema
# Processing Record 43 of Set 3 | vestmannaeyjar
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | yumen
# Processing Record 46 of Set 3 | arrecife
# City not found. Skipping...
# Processing Record 47 of Set 3 | paita
# Processing Record 48 of Set 3 | najran
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 0 of Set 4 | nishihara
# Processing Record 1 of Set 4 | la asuncion
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | sibut
# Processing Record 5 of Set 4 | damghan
# Processing Record 6 of Set 4 | huangchuan
# Processing Record 7 of Set 4 | kijang
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | waitati
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | russell
# Processing Record 12 of Set 4 | syracuse
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | zapolyarnyy
# Processing Record 19 of Set 4 | talara
# Processing Record 20 of Set 4 | san sebastian
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | maniitsoq
# Processing Record 24 of Set 4 | marquette
# Processing Record 25 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 4 | bakchar
# Processing Record 27 of Set 4 | buraydah
# Processing Record 28 of Set 4 | isangel
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | aksu
# Processing Record 31 of Set 4 | lagoa
# Processing Record 32 of Set 4 | arona
# Processing Record 33 of Set 4 | la tuque
# Processing Record 34 of Set 4 | deputatskiy
# Processing Record 35 of Set 4 | luanda
# Processing Record 36 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | olafsvik
# City not found. Skipping...
# Processing Record 39 of Set 4 | xaltianguis
# Processing Record 40 of Set 4 | grand forks
# Processing Record 41 of Set 4 | colac
# Processing Record 42 of Set 4 | salinopolis
# Processing Record 43 of Set 4 | kudahuvadhoo
# Processing Record 44 of Set 4 | kuusamo
# Processing Record 45 of Set 4 | aguimes
# Processing Record 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | batagay-alyta
# Processing Record 48 of Set 4 | whitecourt
# Processing Record 49 of Set 4 | ayan
# Processing Record 0 of Set 5 | georgetown
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | puerto ayora
# Processing Record 4 of Set 5 | kenora
# Processing Record 5 of Set 5 | belaya gora
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | sistranda
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | seydi
# Processing Record 10 of Set 5 | gavle
# Processing Record 11 of Set 5 | hobyo
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | englehart
# Processing Record 14 of Set 5 | anloga
# Processing Record 15 of Set 5 | poum
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 5 | toda bhim
# City not found. Skipping...
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | qui nhon
# City not found. Skipping...
# Processing Record 21 of Set 5 | puerto del rosario
# Processing Record 22 of Set 5 | taksimo
# Processing Record 23 of Set 5 | stourbridge
# Processing Record 24 of Set 5 | amboise
# Processing Record 25 of Set 5 | pasighat
# Processing Record 26 of Set 5 | ugoofaaru
# Processing Record 27 of Set 5 | loukhi
# Processing Record 28 of Set 5 | camacari
# Processing Record 29 of Set 5 | kasungu
# Processing Record 30 of Set 5 | leshukonskoye
# Processing Record 31 of Set 5 | nador
# Processing Record 32 of Set 5 | quelimane
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | saint anthony
# Processing Record 35 of Set 5 | merauke
# Processing Record 36 of Set 5 | greenville
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | inuvik
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | mandiana
# Processing Record 41 of Set 5 | harper
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | shimoda
# Processing Record 44 of Set 5 | concepcion
# Processing Record 45 of Set 5 | saint stephen
# Processing Record 46 of Set 5 | calama
# Processing Record 47 of Set 5 | prince rupert
# Processing Record 48 of Set 5 | novodugino
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 0 of Set 6 | tiarei
# Processing Record 1 of Set 6 | paramonga
# Processing Record 2 of Set 6 | sukumo
# Processing Record 3 of Set 6 | padang
# Processing Record 4 of Set 6 | walvis bay
# Processing Record 5 of Set 6 | jambi
# Processing Record 6 of Set 6 | port hardy
# Processing Record 7 of Set 6 | ordu
# Processing Record 8 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 6 | shache
# Processing Record 10 of Set 6 | mazyr
# Processing Record 11 of Set 6 | eberswalde
# Processing Record 12 of Set 6 | burica
# City not found. Skipping...
# Processing Record 13 of Set 6 | maldonado
# Processing Record 14 of Set 6 | alice springs
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | guerrero
# Processing Record 17 of Set 6 | ayabaca
# Processing Record 18 of Set 6 | wasilla
# Processing Record 19 of Set 6 | yeppoon
# Processing Record 20 of Set 6 | bosaso
# Processing Record 21 of Set 6 | lata
# Processing Record 22 of Set 6 | ewa beach
# Processing Record 23 of Set 6 | henties bay
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | sorong
# Processing Record 27 of Set 6 | gazanjyk
# Processing Record 28 of Set 6 | khandyga
# Processing Record 29 of Set 6 | saint-francois
# Processing Record 30 of Set 6 | ravar
# Processing Record 31 of Set 6 | lengshuitan
# Processing Record 32 of Set 6 | asyut
# Processing Record 33 of Set 6 | vadamadurai
# Processing Record 34 of Set 6 | beyneu
# Processing Record 35 of Set 6 | diapaga
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | athabasca
# Processing Record 38 of Set 6 | komsomolskiy
# Processing Record 39 of Set 6 | porto belo
# Processing Record 40 of Set 6 | kiunga
# Processing Record 41 of Set 6 | djougou
# Processing Record 42 of Set 6 | kremenki
# Processing Record 43 of Set 6 | bonthe
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | qaqortoq
# Processing Record 46 of Set 6 | chase
# Processing Record 47 of Set 6 | ostrovnoy
# Processing Record 48 of Set 6 | montevideo
# Processing Record 49 of Set 6 | broome
# Processing Record 0 of Set 7 | kirakira
# Processing Record 1 of Set 7 | sao jose da coroa grande
# Processing Record 2 of Set 7 | tanjong sepat
# City not found. Skipping...
# Processing Record 3 of Set 7 | sosnytsya
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | saint-joseph
# Processing Record 6 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 7 | bengkulu
# City not found. Skipping...
# Processing Record 8 of Set 7 | buta
# Processing Record 9 of Set 7 | luena
# Processing Record 10 of Set 7 | yining
# Processing Record 11 of Set 7 | madaoua
# Processing Record 12 of Set 7 | suozhen
# Processing Record 13 of Set 7 | falakata
# Processing Record 14 of Set 7 | lumeje
# Processing Record 15 of Set 7 | tigre
# Processing Record 16 of Set 7 | evensk
# Processing Record 17 of Set 7 | moussoro
# Processing Record 18 of Set 7 | matinha
# Processing Record 19 of Set 7 | contratacion
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | sooke
# Processing Record 22 of Set 7 | galesong
# Processing Record 23 of Set 7 | kloulklubed
# Processing Record 24 of Set 7 | jalu
# Processing Record 25 of Set 7 | dzilam gonzalez
# Processing Record 26 of Set 7 | rognan
# Processing Record 27 of Set 7 | dudinka
# Processing Record 28 of Set 7 | abonnema
# Processing Record 29 of Set 7 | sergeyevka
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | pisz
# Processing Record 33 of Set 7 | yarada
# Processing Record 34 of Set 7 | eyrarbakki
# Processing Record 35 of Set 7 | navapur
# City not found. Skipping...
# Processing Record 36 of Set 7 | constitucion
# Processing Record 37 of Set 7 | road town
# Processing Record 38 of Set 7 | kyshtovka
# Processing Record 39 of Set 7 | saint-augustin
# Processing Record 40 of Set 7 | arlit
# Processing Record 41 of Set 7 | mayo
# Processing Record 42 of Set 7 | tamandare
# Processing Record 43 of Set 7 | almaznyy
# Processing Record 44 of Set 7 | wanning
# Processing Record 45 of Set 7 | salym
# Processing Record 46 of Set 7 | tuatapere
# Processing Record 47 of Set 7 | mitsamiouli
# Processing Record 48 of Set 7 | livingston
# Processing Record 49 of Set 7 | portland
# Processing Record 0 of Set 8 | chimoio
# Processing Record 1 of Set 8 | torbay
# Processing Record 2 of Set 8 | maceio
# Processing Record 3 of Set 8 | muros
# Processing Record 4 of Set 8 | taltal
# Processing Record 5 of Set 8 | lac du bonnet
# Processing Record 6 of Set 8 | deloraine
# Processing Record 7 of Set 8 | waipawa
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | riyadh
# Processing Record 10 of Set 8 | bud
# Processing Record 11 of Set 8 | shahr-e babak
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | amga
# Processing Record 14 of Set 8 | leh
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | belle fourche
# Processing Record 17 of Set 8 | roros
# Processing Record 18 of Set 8 | gat
# Processing Record 19 of Set 8 | taburao
# City not found. Skipping...
# Processing Record 20 of Set 8 | davenport
# Processing Record 21 of Set 8 | kruisfontein
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | moroni
# Processing Record 25 of Set 8 | nivala
# Processing Record 26 of Set 8 | balikpapan
# Processing Record 27 of Set 8 | coquimbo
# Processing Record 28 of Set 8 | red bluff
# Processing Record 29 of Set 8 | oktyabrskoye
# Processing Record 30 of Set 8 | tasiilaq
# Processing Record 31 of Set 8 | jinhua
# Processing Record 32 of Set 8 | sabang
# Processing Record 33 of Set 8 | normandin
# Processing Record 34 of Set 8 | bayshore gardens
# Processing Record 35 of Set 8 | brae
# Processing Record 36 of Set 8 | salinas
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | san patricio
# Processing Record 39 of Set 8 | tlahualilo
# City not found. Skipping...
# Processing Record 40 of Set 8 | xichang
# Processing Record 41 of Set 8 | atambua
# Processing Record 42 of Set 8 | kaeo
# Processing Record 43 of Set 8 | verkhnyaya toyma
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | victor harbor
# Processing Record 46 of Set 8 | gravdal
# Processing Record 47 of Set 8 | shingu
# Processing Record 48 of Set 8 | taoudenni
# Processing Record 49 of Set 8 | san felipe
# Processing Record 0 of Set 9 | odessa
# Processing Record 1 of Set 9 | stornoway
# City not found. Skipping...
# Processing Record 2 of Set 9 | impfondo
# Processing Record 3 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 9 | kutum
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | borba
# Processing Record 7 of Set 9 | shkotovo-26
# City not found. Skipping...
# Processing Record 8 of Set 9 | carballo
# Processing Record 9 of Set 9 | bari
# Processing Record 10 of Set 9 | tabas
# Processing Record 11 of Set 9 | acarau
# City not found. Skipping...
# Processing Record 12 of Set 9 | nizwa
# Processing Record 13 of Set 9 | kushima
# Processing Record 14 of Set 9 | jiangyou
# Processing Record 15 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 16 of Set 9 | tecozautla
# Processing Record 17 of Set 9 | hay river
# Processing Record 18 of Set 9 | lompoc
# Processing Record 19 of Set 9 | kaspiyskiy
# Processing Record 20 of Set 9 | iqaluit
# Processing Record 21 of Set 9 | angoche
# Processing Record 22 of Set 9 | chapleau
# Processing Record 23 of Set 9 | zhigansk
# Processing Record 24 of Set 9 | san juan
# Processing Record 25 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | shakawe
# Processing Record 28 of Set 9 | kazachinskoye
# Processing Record 29 of Set 9 | katsuura
# Processing Record 30 of Set 9 | smithers
# Processing Record 31 of Set 9 | tighina
# Processing Record 32 of Set 9 | hervey bay
# Processing Record 33 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 34 of Set 9 | nome
# Processing Record 35 of Set 9 | yarmouth
# Processing Record 36 of Set 9 | tecoanapa
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | san policarpo
# Processing Record 39 of Set 9 | palana
# Processing Record 40 of Set 9 | santa cruz
# Processing Record 41 of Set 9 | faanui
# Processing Record 42 of Set 9 | sawakin
# Processing Record 43 of Set 9 | effium
# Processing Record 44 of Set 9 | ostersund
# Processing Record 45 of Set 9 | igdir
# Processing Record 46 of Set 9 | lewistown
# Processing Record 47 of Set 9 | davila
# Processing Record 48 of Set 9 | araouane
# Processing Record 49 of Set 9 | wakkanai
# Processing Record 0 of Set 10 | batemans bay
# Processing Record 1 of Set 10 | dayong
# Processing Record 2 of Set 10 | birobidzhan
# Processing Record 3 of Set 10 | nalut
# Processing Record 4 of Set 10 | seymchan
# Processing Record 5 of Set 10 | arman
# Processing Record 6 of Set 10 | pitimbu
# Processing Record 7 of Set 10 | guerrero negro
# Processing Record 8 of Set 10 | sargatskoye
# Processing Record 9 of Set 10 | umm kaddadah
# Processing Record 10 of Set 10 | gigmoto
# Processing Record 11 of Set 10 | lokoja
# Processing Record 12 of Set 10 | hasaki
# Processing Record 13 of Set 10 | kuminskiy
# Processing Record 14 of Set 10 | tessalit
# Processing Record 15 of Set 10 | severnoye
# Processing Record 16 of Set 10 | malaya vishera
# Processing Record 17 of Set 10 | sumoto
# Processing Record 18 of Set 10 | altamira
# Processing Record 19 of Set 10 | hovd
# Processing Record 20 of Set 10 | malpe
# Processing Record 21 of Set 10 | hambantota
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | dwarka
# Processing Record 24 of Set 10 | nyagan
# Processing Record 25 of Set 10 | jeremie
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | novolvovsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | pringsewu
# Processing Record 29 of Set 10 | peniche
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | fushun
# Processing Record 32 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 10 | yulara
# Processing Record 34 of Set 10 | kamaishi
# Processing Record 35 of Set 10 | richards bay
# Processing Record 36 of Set 10 | aripuana
# Processing Record 37 of Set 10 | long branch
# Processing Record 38 of Set 10 | ocean city
# Processing Record 39 of Set 10 | mackay
# Processing Record 40 of Set 10 | astoria
# Processing Record 41 of Set 10 | bolobo
# Processing Record 42 of Set 10 | paamiut
# Processing Record 43 of Set 10 | bousso
# City not found. Skipping...
# Processing Record 44 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 10 | snezhnogorsk
# Processing Record 46 of Set 10 | kayerkan
# Processing Record 47 of Set 10 | port blair
# Processing Record 48 of Set 10 | balakhninskiy
# Processing Record 49 of Set 10 | oussouye
# Processing Record 0 of Set 11 | la ronge
# Processing Record 1 of Set 11 | kaisiadorys
# Processing Record 2 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 11 | namibe
# Processing Record 4 of Set 11 | upata
# Processing Record 5 of Set 11 | mantua
# Processing Record 6 of Set 11 | makokou
# Processing Record 7 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 11 | ersekvadkert
# Processing Record 9 of Set 11 | chulman
# Processing Record 10 of Set 11 | thunder bay
# Processing Record 11 of Set 11 | nelson bay
# Processing Record 12 of Set 11 | slave lake
# Processing Record 13 of Set 11 | phan thiet
# Processing Record 14 of Set 11 | norfolk
# Processing Record 15 of Set 11 | oranjestad
# Processing Record 16 of Set 11 | north bend
# Processing Record 17 of Set 11 | linhares
# Processing Record 18 of Set 11 | guiratinga
# Processing Record 19 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 11 | tibana
# Processing Record 21 of Set 11 | valdivia
# Processing Record 22 of Set 11 | tigil
# Processing Record 23 of Set 11 | namtsy
# Processing Record 24 of Set 11 | kot addu
# Processing Record 25 of Set 11 | ambon
# Processing Record 26 of Set 11 | trifesti
# Processing Record 27 of Set 11 | ulaanbaatar
# Processing Record 28 of Set 11 | huarmey
# Processing Record 29 of Set 11 | beterou
# Processing Record 30 of Set 11 | male
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 11 | griffith
# Processing Record 34 of Set 11 | muisne
# Processing Record 35 of Set 11 | grafton
# Processing Record 36 of Set 11 | fare
# Processing Record 37 of Set 11 | socorro
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | mount isa
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | vanimo
# Processing Record 42 of Set 11 | lazaro cardenas
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | camacha
# Processing Record 45 of Set 11 | lorengau
# Processing Record 46 of Set 11 | ahipara
# Processing Record 47 of Set 11 | carutapera
# Processing Record 48 of Set 11 | andra
# Processing Record 49 of Set 11 | pocone
# Processing Record 0 of Set 12 | eregli
# Processing Record 1 of Set 12 | klaksvik
# Processing Record 2 of Set 12 | seoul
# Processing Record 3 of Set 12 | umba
# Processing Record 4 of Set 12 | sarankhola
# Processing Record 5 of Set 12 | floro
# Processing Record 6 of Set 12 | helong
# Processing Record 7 of Set 12 | mercedes
# Processing Record 8 of Set 12 | fayetteville
# Processing Record 9 of Set 12 | danielskuil
# Processing Record 10 of Set 12 | namwala
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | moree
# Processing Record 13 of Set 12 | salur
# Processing Record 14 of Set 12 | jiaozuo
# Processing Record 15 of Set 12 | warmbad
# Processing Record 16 of Set 12 | oistins
# Processing Record 17 of Set 12 | skibbereen
# Processing Record 18 of Set 12 | nabisar
# Processing Record 19 of Set 12 | ipora
# City not found. Skipping...
# Processing Record 20 of Set 12 | damietta
# Processing Record 21 of Set 12 | angra dos reis
# Processing Record 22 of Set 12 | lavrentiya
# Processing Record 23 of Set 12 | mackenzie
# Processing Record 24 of Set 12 | kiama
# Processing Record 25 of Set 12 | kavieng
# Processing Record 26 of Set 12 | valparaiso
# Processing Record 27 of Set 12 | umm lajj
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 12 | charters towers
# Processing Record 31 of Set 12 | zaykovo
# Processing Record 32 of Set 12 | pangnirtung
# Processing Record 33 of Set 12 | baherden
# Processing Record 34 of Set 12 | vardo
# Processing Record 35 of Set 12 | murchison
# Processing Record 36 of Set 12 | kjopsvik
# Processing Record 37 of Set 12 | tual
# Processing Record 38 of Set 12 | metro
# Processing Record 39 of Set 12 | bonavista
# Processing Record 40 of Set 12 | huilong
# Processing Record 41 of Set 12 | cervo
# Processing Record 42 of Set 12 | te anau
# Processing Record 43 of Set 12 | sambava
# Processing Record 44 of Set 12 | razvilnoye
# Processing Record 45 of Set 12 | kununurra
# Processing Record 46 of Set 12 | iguala
# Processing Record 47 of Set 12 | harsin
# Processing Record 48 of Set 12 | ufa
# Processing Record 49 of Set 12 | quanzhou
# Processing Record 0 of Set 13 | batangafo
# Processing Record 1 of Set 13 | zelenoborskiy
# Processing Record 2 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 13 | victoria point
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          550
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      mataura         100      NZ  1572937379        81 -46.19  168.86
# 1    busselton          85      AU  1572937379        37 -33.64  115.35
# 2      ushuaia          90      AR  1572937111        80 -54.81  -68.31
# 3     chabahar           0      IR  1572937379        43  25.29   60.65
# 4  tuktoyaktuk          75      CA  1572937379        92  69.44 -133.03
#
#    Max Temp  Wind Speed
# 0     53.01        8.01
# 1     75.00       16.37
# 2     39.20       10.29
# 3     87.80        6.93
# 4     15.80        6.93

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Desktop/Shreya_Github/Python_API_Challenge/Fig4.png")

# Show plot
plt.show()
